# %% [markdown]
# # Download a dataset

# %% [markdown]
# may be need to login to download dataset

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset
dataset=load_dataset('atlasia/Atlaset')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from datasets import load_dataset
#       2 dataset=load_dataset('atlasia/Atlaset')
#
# ModuleNotFoundError: No module named 'datasets'

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Create the sequence of text

# %%
from tqdm import tqdm

data=[]
rows=dataset['train']['text']
for row in tqdm(rows):
    data.appendd(row)

rows=dataset['test']['text']
for row in tqda(rows):
    data.append(row)

print(len(" ".join(data)))

# %%
# storing the sequence

with open("../data/AtlaSetCombined.txt", "w") as f:
    f.write(" ".join(data))
